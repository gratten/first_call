# %%
# f = open('Daily Update_ 19_30_02 01 OCT 2020.eml', 'r')

# %%
# import email
# from email import policy
# from email.parser import BytesParser
# import glob
file_list = glob.glob('*.eml') # returns list of files

# %%
len(file_list)
# Out:
# 14

# %%
msg_list = []

for num in range(len(file_list)):
    with open(file_list[num], 'rb') as fp:  # select a specific email file from the list
        msg = BytesParser(policy=policy.default).parse(fp)
        msg_list.append(msg)

# %%
target = '<td=>Net Sales:</td>'

# %%
# my_string="hello python world , i'm a beginner "
# print my_string.split("world",1)[1]

# %%
# for msg in msg_list:
#     my_val = msg.split(target, 1)[1]

# %%
for msg in msg_list:
    print(msg)
# Out:
# Delivered-To: grattenward@gmail.com
# Received: by 2002:a17:906:1fcf:0:0:0:0 with SMTP id e15csp835419ejt;
#         Thu, 1 Oct 2020 16:30:14 -0700 (PDT)
# X-Google-Smtp-Source:
#  ABdhPJzyddbcjgPs2YaI+VrYFVeavDuXS2j2iw5MohkbZ+IEapN4A8Ctx8bhR57SyhW1j6wHKkrY
# X-Received: by 2002:a25:14d5:: with SMTP id
#  204mr14060411ybu.162.1601595014854;        Thu, 01 Oct 2020 16:30:14 -0700
#  (PDT)
# ARC-Seal: i=1; a=rsa-sha256; t=1601595014; cv=none;
#         d=google.com; s=arc-20160816;
#         b=cRlhm8ZboLzMIrG7yiEh9W8tIYb2dz2ebhnSaIMztXMhmaWrj9iKbNSHWxZoDsrrVr
#          EBlSds0oH/DdKt3R4k5/oiwdCirr8M+jKM/SLCxkZyY/bf5u6SelDV8UHrEFLMl6QN6h
#          iCSoJKV0hnafVLa3oDkGejqbI9gohX6a4QsZbAPU6+wC4yB+AHFyoR3o6q4DZ4/9GTzM
#          F3p4Aha1ncLlPqds5A/17Uqrn36nGUBXpQsrXWvWxiLbgZtMJz9mLA8IT1gdJc6pLZHP
#          M93oKqOaxpI4LTf6IuM6u7MGAyD3KD36PJdM+EOrKKvOVRuMODwKYzOF/iVPAi/KJ6EB
#          llAA==
# ARC-Message-Signature: i=1; a=rsa-sha256; c=relaxed/relaxed; d=google.com;
#  s=arc-20160816;
# ...
